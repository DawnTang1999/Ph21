# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Part I Biased coin tossing: compute Prob()
# Ignore the normalization factor Prob(H|Data)

# Probability of getting number of heads given probability of getting heads: Prob(h|H)
# n is the number of trials, h is the number of heads, H us the probability of getting heads
def P_D_H(n, h, H):
    if n < h:
        return 0
    prob = np.math.factorial(n) / (np.math.factorial(h)*np.math.factorial(n-h)) * H**h * (1-H)**(n-h)
    return prob

# array of n values
# take in exponent and generate array of 1,2,4,...,2**N
def n_array(N):
    n = np.zeros(N+1)
    for a in range(N+1):
        n[a] = 2**a
    return n
n = n_array(5)

# Prob(H) = constant = 1, probabaility of having parameter H
# The number of heads is h = 1
len_H = 100
h = 1
H = np.linspace(0, 1, len_H)
prob_const_H = np.zeros(len_H)
for i in range(len(n)):
    for j in range(len_H):
        prob_const_H[j] = P_D_H(n[i], h, H[j])
    plt.plot(H, prob_const_H)
    plt.title('P(H|h = ' + str(h) +') with n = '+str(n[i])+ '(constant)')
    plt.xlabel('H')
    plt.ylabel('P(H|h = ' + str(h) + ')')
    plt.show()

# %%
# Choose gaussian that is centered at H = 0.5, mu = 0.5
# pick standard deviation sigma = 0.15 so that +- 3 sigma is within [0,1]
sigma = 0.15
mu = 0.5
H_gaus = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-1/2 * ((H - mu)/sigma)**2)

# within 1 sigma
start1 = int((mu - sigma) * len_H)
end1 = int((mu + sigma) * len_H)
H_gaus_1_sigma = H[start1 : end1]
prob_H_gaus_1 = np.zeros(len(H_gaus_1_sigma))
for i in range(len(n)):
    for j in range(len(H_gaus_1_sigma)):
        prob_H_gaus_1[j] = P_D_H(n[i], h, H_gaus_1_sigma[j]) * H_gaus[j+start1]
    plt.plot(H_gaus_1_sigma, prob_H_gaus_1)
    plt.title('P(H|h = ' + str(h) +') with n = ' + str(n[i]) + ' gaussian within 1 std')
    plt.xlabel('H')
    plt.ylabel('P(H|h = ' + str(h) + ')')
    plt.show()

# %%
# 3 sigmas away from center of gaussian distribution
start3 = int(len_H / 2 - 3 * sigma)
end3 = int(start3 + sigma * len_H)
H_gaus_3_sigma = H[start3: end3]
prob_H_gaus_3 = np.zeros(len(H_gaus_3_sigma))
for i in range(len(n)):
    for j in range(len(H_gaus_3_sigma)):
        prob_H_gaus_3[j] = P_D_H(n[i], h, H_gaus_3_sigma[j]) * H_gaus[j+start3]
    plt.plot(H_gaus_3_sigma, prob_H_gaus_3)
    plt.title('P(H|h = ' + str(h) +') with n = ' + str(n[i]) + ' gaussian 3 std')
    plt.xlabel('H')
    plt.ylabel('P(H|h = ' + str(h) + ')')
    plt.show()
